# %%
import pandas as pd

# %%
filepath = r"metrics/benchmark_runs/model_benchmarked_results/1.3b-optimized-tokens=111-samples=500.pkl"
df = pd.read_pickle(filepath)
df
# Out:
#                                                    src  \
# 0    david schwartz was unaware of the fact that he...
# 1                                 we 'll be safe here.
# 2                                we 'll talk about it.
# 3                                  What was your plan?
# 4    historians can make a credible case that the p...
# ..                                                 ...
# 495  adler took a moment to consider that, and nodded.
# 496                                      Five minutes.
# 497       i, uh -- i brought you, uh -- i brought you.
# 498                          Every child is different.
# 499                        Qatar motorcycle Grand Prix
#
#                                                 target  bartscore  bleuscore  \
# 0    david schwartz was unaware of how narrowly he ...  -2.400615   0.396709
# 1                                 we'il be safe here .  -3.485580   0.000000
# 2    why do n't you come in and we 'll talk about it .  -3.939687   0.135016
# 3                                  What was your plan?  -0.602847   1.000000
# 4    historians can make a credible case that perio...  -2.147272   0.353486
# ..                                                 ...        ...        ...
# 495  adler took a few seconds to consider that , th...  -2.633909   0.000000
# 496                Ladies and gentlemen, five minutes.  -2.346147   0.000000
# 497                    i , uh -- i brought you , uh --  -2.529754   0.289978
# 498                          Every child is different.  -0.453974   1.000000
# 499                        Qatar motorcycle Grand Prix  -1.097775   1.000000
#
#      rouge1_fmeasure  rouge1_precision  rouge1_recall  rouge2_fmeasure  \
# 0           0.702703          0.684211       0.722222         0.514286
# 1           0.800000          0.800000       0.800000         0.500000
# 2           0.555556          1.000000       0.384615         0.500000
# 3           1.000000          1.000000       1.000000         1.000000
# 4           0.745098          0.791667       0.703704         0.571429
# ..               ...               ...            ...              ...
# 495         0.700000          0.777778       0.636364         0.444444
# 496         0.571429          1.000000       0.400000         0.400000
# 497         0.800000          0.666667       1.000000         0.769231
# 498         1.000000          1.000000       1.000000         1.000000
# 499         1.000000          1.000000       1.000000         1.000000
#
#      rouge2_precision  rouge2_recall  rougeL_fmeasure  rougeL_precision  \
# 0            0.500000       0.529412         0.648649          0.631579
# 1            0.500000       0.500000         0.800000          0.800000
# 2            1.000000       0.333333         0.555556          1.000000
# 3            1.000000       1.000000         1.000000          1.000000
# 4            0.608696       0.538462         0.705882          0.750000
# ..                ...            ...              ...               ...
# 495          0.500000       0.400000         0.700000          0.777778
# 496          1.000000       0.250000         0.571429          1.000000
# 497          0.625000       1.000000         0.800000          0.666667
# 498          1.000000       1.000000         1.000000          1.000000
# 499          1.000000       1.000000         1.000000          1.000000
#
#      rougeL_recall  rougeLsum_fmeasure  rougeLsum_precision  rougeLsum_recall
# 0         0.666667            0.648649             0.631579          0.666667
# 1         0.800000            0.800000             0.800000          0.800000
# 2         0.384615            0.555556             1.000000          0.384615
# 3         1.000000            1.000000             1.000000          1.000000
# 4         0.666667            0.705882             0.750000          0.666667
# ..             ...                 ...                  ...               ...
# 495       0.636364            0.700000             0.777778          0.636364
# 496       0.400000            0.571429             1.000000          0.400000
# 497       1.000000            0.800000             0.666667          1.000000
# 498       1.000000            1.000000             1.000000          1.000000
# 499       1.000000            1.000000             1.000000          1.000000
#
# [500 rows x 16 columns]

# %%
df.mean()
# Out:
# C:\Users\weipy\AppData\Local\Temp\ipykernel_5208\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# bartscore             -2.157947
# bleuscore              0.342787
# rouge1_fmeasure        0.835004
# rouge1_precision       0.856809
# rouge1_recall          0.838207
# rouge2_fmeasure        0.737537
# rouge2_precision       0.756071
# rouge2_recall          0.743406
# rougeL_fmeasure        0.830460
# rougeL_precision       0.852231
# rougeL_recall          0.833340
# rougeLsum_fmeasure     0.830814
# rougeLsum_precision    0.852436
# rougeLsum_recall       0.833801
# dtype: float64

# %%
filepath = r"metrics/benchmark_runs/model_benchmarked_results/1.3b-fine-tuned-samples=500.pkl"
df = pd.read_pickle(filepath)
df
